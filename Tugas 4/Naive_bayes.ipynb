# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_excel('datakelulusanmahasiswaa.xls')
x = dataset.iloc[:, [0,1]].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [['ANIK WIDAYANTI' 'PEREMPUAN']
#  ['DWI HESTYNA PRIHASTANTY' 'PEREMPUAN']
#  ['MURYA ARIEF BASUKI' 'PEREMPUAN']
#  ['NANIK SUSANTI' 'PEREMPUAN']
#  ['RIFKA ISTIQFARINA' 'PEREMPUAN']
#  ['SUHARYONO' 'LAKI - LAKI']
#  ['FARIKHATUN NAZLI' 'PEREMPUAN']
#  ['FIFI SUNALISA' 'PEREMPUAN']
#  ['HENDRIK MULIYANTO' 'PEREMPUAN']
#  ['IMAM AGUNG RIBOWO' 'PEREMPUAN']
#  ['IMAM SANTOSA' 'PEREMPUAN']
#  ['IRFAN EKO WAHYUDI' 'PEREMPUAN']
#  ['IWAN HAMBALI' 'PEREMPUAN']
#  ['M SYAIFULLAH' 'PEREMPUAN']
#  ['DIANA LAILY FITHRI' 'PEREMPUAN']
#  ['DONNY PRABOWO' 'LAKI - LAKI']
#  ['EDI JATMIKO' 'PEREMPUAN']
#  ['ADI SUBEKTI' 'LAKI - LAKI']
#  ['AHMAD IBROZI' 'LAKI - LAKI']
#  ['ANDI HARDIANTO' 'LAKI - LAKI']
#  ['ANDI SUNARWAN' 'LAKI - LAKI']
#  ['ANNY AZIZAH' 'LAKI - LAKI']
#  ['ARIEF PRAM WAHYUDI' 'LAKI - LAKI']
#  ['DENNY SELA PUTROWIBOWO' 'LAKI - LAKI']
#  ['MARTHINA FLAVERIA' 'LAKI - LAKI']
#  ['MASLUH JAMIL' 'LAKI - LAKI']
#  ['MURDIANTORO' 'LAKI - LAKI']
#  ['NAILI ROHMAH' 'PEREMPUAN']
#  ['NASRUL SAFARAH' 'LAKI - LAKI']
#  ['NOOR KAMALUDDIN MALIK' 'LAKI - LAKI']
#  ['ROHANA MIRAWATI' 'LAKI - LAKI']
#  ['SANDY YUDHA NUGRAHA' 'LAKI - LAKI']
#  ['SISKA LIANAWATI' 'LAKI - LAKI']
#  ['SRI MINUK ISWATI' 'LAKI - LAKI']
#  ['SUDANDING DWI SUPRABANA' 'LAKI - LAKI']
#  ['SUGIYANTO' 'LAKI - LAKI']
#  ['SUSI  HANDAYANI' 'LAKI - LAKI']
#  ['SUTOPO' 'LAKI - LAKI']
#  ['TOTOK ANTON ARIBOWO' 'LAKI - LAKI']
#  ['ADI DARMADI' 'LAKI - LAKI']
#  ['EKO JAUHARI SAPUTRO' 'LAKI - LAKI']
#  ['HARMINTO MULYO' 'LAKI - LAKI']
#  ['HERI PURWANTO' 'LAKI - LAKI']
#  ['MIFTACHUR RIDHO' 'LAKI - LAKI']
#  ['TATIK HIKMAWATI' 'LAKI - LAKI']
#  ['USWATUN KHASANAH' 'LAKI - LAKI']
#  ["A SYAFI'I" 'LAKI - LAKI']
#  ["ABDUL GHOFFAR ISMA'IL" 'LAKI - LAKI']
#  ['ACHMAD FAHMI AQWA' 'LAKI - LAKI']
#  ['ADY PRASETIA' 'LAKI - LAKI']
#  ['AGUNG WIDODO' 'LAKI - LAKI']
#  ['AGUS SUSILO' 'LAKI - LAKI']
#  ['AGUS BUDI UTOMO' 'LAKI - LAKI']
#  ['AGUS RIYANTO' 'LAKI - LAKI']
#  ['ALINA INDRAWATI' 'PEREMPUAN']
#  ['ANDY MAHENDRA' 'LAKI - LAKI']
#  ['ARIEF IRFANDIANSYAH' 'LAKI - LAKI']
#  ['ARIEF SETIAWAN' 'LAKI - LAKI']
#  ['BAGUS WIBOWO HERRU PRIHANTO' 'LAKI - LAKI']
#  ['DEFI MAULA KHORIDA' 'PEREMPUAN']
#  ['DEVI RIESTYANINGSIH' 'PEREMPUAN']
#  ['DIAH KUSUMANINGTYAS' 'PEREMPUAN']
#  ['EDI HARIYANTO' 'LAKI - LAKI']
#  ['EDI PURNOMO' 'LAKI - LAKI']
#  ['EMA SYAROH' 'PEREMPUAN']
#  ['EMAN PRASOJO' 'LAKI - LAKI']
#  ['EMAWANTI' 'PEREMPUAN']
#  ['ERFANA SETIYANINGRUM' 'PEREMPUAN']
#  ['FARCHAN NOVE INDRIYANTO' 'LAKI - LAKI']
#  ['FITRIA HANDAYANI' 'PEREMPUAN']
#  ['FITYATUN FATAYAH' 'PEREMPUAN']
#  ['HAROZUM' 'PEREMPUAN']
#  ['HERMAWAN BUDI HARTONO' 'LAKI - LAKI']
#  ['HERU NOR RACHMAD' 'LAKI - LAKI']
#  ['INDRI ERNAMAWATI' 'PEREMPUAN']
#  ['IWAN SETYO ASMOKO' 'LAKI - LAKI']
#  ["KHAMIM MASYFU'I" 'LAKI - LAKI']
#  ['KOMARUDIN FARUQ' 'LAKI - LAKI']
#  ['LINA NAILAL MUNA' 'PEREMPUAN']
#  ['MEILINDA IKA WIJAYANTI' 'PEREMPUAN']
#  ['MIFTAHUL HUDA' 'LAKI - LAKI']
#  ['MOCH LUTFIANTO' 'LAKI - LAKI']
#  ['MOCHAMAD IRWANSYAH' 'LAKI - LAKI']
#  ['MOH ERIK CHANDRA IRVANA' 'LAKI - LAKI']
#  ['MOKHAMAD ALEX KHOIRUDIN' 'LAKI - LAKI']
#  ['MUCHAMMAD BAHRUDIN' 'LAKI - LAKI']
#  ['MUHAMMAD ABDUH' 'LAKI - LAKI']
#  ['MUHAMMAD ABDUL AZIS' 'LAKI - LAKI']
#  ['MUHAMMAD AMINAN' 'LAKI - LAKI']
#  ['MUHAMMAD YASIN YUSUF' 'LAKI - LAKI']
#  ['NISWATUL ALIYAH' 'PEREMPUAN']
#  ['NOOR MUHAMMAD AFIF' 'LAKI - LAKI']
#  ['NOVAN AIS SETIANSAH' 'LAKI - LAKI']
#  ['PUTRI KURNIA HANDAYANI' 'PEREMPUAN']
#  ['REZA PAHLEVI' 'LAKI - LAKI']
#  ['RINA WARDANI' 'PEREMPUAN']
#  ['ROFIDA RONING MAHANONDA' 'PEREMPUAN']
#  ['RUDIYANTI SETIASIH' 'PEREMPUAN']
#  ['SHOFIA NUR JAMILA' 'PEREMPUAN']
#  ['SIGIT SETYO ATMOKO' 'PEREMPUAN']
#  ['SUGIYANTO' 'LAKI - LAKI']
#  ['SUMARLAN' 'LAKI - LAKI']
#  ['SUYONO' 'LAKI - LAKI']
#  ['TAUFIK SETYAWAN' 'LAKI - LAKI']
#  ['TRI MULYANTO' 'LAKI - LAKI']
#  ['TUGIYO' 'LAKI - LAKI']
#  ['TUTIK KHOTIMAH' 'PEREMPUAN']
#  ['YUDA LINDA PRATIWI' 'PEREMPUAN']
#  ['YUSTINUS ARI SETIAWAN' 'LAKI - LAKI']
#  ['DANNY NOVRIYANTO' 'LAKI - LAKI']
#  ['PRATIWI PUJIASTUTI' 'PEREMPUAN']
#  ['EDY KUSMANTO' 'PEREMPUAN']
#  ['LAILI QODRIYAH' 'PEREMPUAN']
#  ['SUGENG RIYANTO' 'LAKI - LAKI']
#  ['GUNA SETIAWAN' 'LAKI - LAKI']
#  ['MASYKURI' 'LAKI - LAKI']
#  ['MUTIARA FANNY' 'PEREMPUAN']
#  ['HERU WIJAYANTO' 'LAKI - LAKI']
#  ['SYARIEF WIRA ADMAJA' 'LAKI - LAKI']
#  ['ISMI NUR FAJRIAH' 'PEREMPUAN']
#  ['ARUM PURWANINGSIH' 'PEREMPUAN']
#  ['MUHKHAMAD FAKHRUL HIDAYAT' 'LAKI - LAKI']
#  ['AGUSTINA SETIONINGSIH' 'PEREMPUAN']
#  ['DWI SISWANTO' 'LAKI - LAKI']
#  ['KUMALA DEWI' 'LAKI - LAKI']
#  ['NIRWANA SATRIA PAMBUDI' 'LAKI - LAKI']
#  ['IKA MUSTIANA' 'PEREMPUAN']
#  ['AYU NAWAKSARI' 'PEREMPUAN']
#  ['NOOR FAIS' 'PEREMPUAN']
#  ['INDAH NOR KHAYATI' 'PEREMPUAN']
#  ['MUHAMMAD ARIF WIBOWO' 'LAKI - LAKI']
#  ['MOHAMAD ABDUL AZIS' 'LAKI - LAKI']
#  ['WAHYUNI' 'PEREMPUAN']
#  ['MUHAMAD FAUZI' 'LAKI - LAKI']
#  ['FITRIANA MASRUROH' 'PEREMPUAN']
#  ['MOHAMAD ASNAWI' 'LAKI - LAKI']
#  ['MARWANTO WIJANARKO' 'LAKI - LAKI']
#  ['NOOR ISYA' 'LAKI - LAKI']
#  ['RIZAL BACHTIAR' 'LAKI - LAKI']
#  ['ISNANTO HENDRO YULIHARSO' 'LAKI - LAKI']
#  ['WAHYU SETIYA BUDI' 'LAKI - LAKI']
#  ['MIFTAKHULIL SETIYANING HIDAYAH' 'PEREMPUAN']
#  ['WIWID WAHYUDI' 'LAKI - LAKI']
#  ['GAMA FARID DENA' 'LAKI - LAKI']
#  ['SAIRUN NICHLAH' 'PEREMPUAN']
#  ['UMMIA WULAN SARI' 'PEREMPUAN']
#  ['KARSONO HENDI' 'LAKI - LAKI']
#  ['EVA ADITYA' 'PEREMPUAN']
#  ['ANDRE EKA SETYAWAN' 'LAKI - LAKI']
#  ['JOHAN MAULANA' 'LAKI - LAKI']
#  ['SAIFUL ANAM' 'LAKI - LAKI']
#  ['NURUL KHOIRIYAH' 'PEREMPUAN']
#  ['HERU DARMAWAN' 'LAKI - LAKI']
#  ["NI'MATUL KHASANAH" 'PEREMPUAN']
#  ['PURWADI' 'LAKI - LAKI']
#  ['TRI PUJI LESTARI' 'PEREMPUAN']
#  ['TAUFIK RAMADHAN' 'LAKI - LAKI']
#  ['MOH SYAIKHUDDIN' 'LAKI - LAKI']
#  ['MOH AINUL YAQIN' 'LAKI - LAKI']
#  ['FIRMAN HAQIQI' 'LAKI - LAKI']
#  ['DEWI KARYASARI' 'PEREMPUAN']
#  ['ROSIDI' 'LAKI - LAKI']
#  ['MUH SAIFUL MUBAROK' 'LAKI - LAKI']
#  ['MIFTAKHUL HABIB' 'LAKI - LAKI']
#  ['GUNUNG WICAKSONO' 'LAKI - LAKI']
#  ['ANIK MURWATI' 'PEREMPUAN']
#  ['MUHAMMAD TAHRIR FATHONY' 'LAKI - LAKI']
#  ['PUTRI RETNO ARIYANI' 'PEREMPUAN']
#  ['MOCHAMAD IDRIS' 'LAKI - LAKI']
#  ['ERVINA DWI WIJAYANTI' 'PEREMPUAN']
#  ['ADI JOKO MULYONO' 'LAKI - LAKI']
#  ['DANANG MAHENDRA' 'LAKI - LAKI']
#  ['NILA OCTARINA' 'PEREMPUAN']
#  ['M IMAM MUSLIMIN' 'LAKI - LAKI']
#  ['NOOR FARIDA' 'PEREMPUAN']
#  ['ARIE RETNO WATI' 'PEREMPUAN']
#  ['SUNARSO' 'LAKI - LAKI']
#  ['DEWI ASTUTI' 'PEREMPUAN']
#  ["KHOTIMATUS SA'ADAH" 'PEREMPUAN']
#  ['EKA SETIYANI' 'PEREMPUAN']
#  ['MUHAMMAD SETIAWAN' 'LAKI - LAKI']
#  ["ULFAH NOR SA'ADAH" 'PEREMPUAN']
#  ['SITI SUSANAH' 'PEREMPUAN']
#  ['ARDI SETIAWAN' 'LAKI - LAKI']
#  ['BADRUDDIN' 'LAKI - LAKI']
#  ['PRASTIWI SETIYOWATI' 'PEREMPUAN']
#  ['ROBI KORNIYAWAN' 'LAKI - LAKI']
#  ['EVY DIAH HAPSARI' 'PEREMPUAN']
#  ['NISFISYA MUSWARDINI' 'PEREMPUAN']
#  ['MOHAMMAD RIFQI ABDILLAH' 'LAKI - LAKI']
#  ['MOH IQBAL HAKIM' 'LAKI - LAKI']
#  ['IRWAN HIDAYAT' 'LAKI - LAKI']
#  ['AFTONAL FALAKH' 'LAKI - LAKI']
#  ['SITI CHODIROH' 'PEREMPUAN']
#  ['ENI ISNAWATI' 'PEREMPUAN']
#  ['AKHMAD ZAINUDIN' 'LAKI - LAKI']
#  ['ARIF BUDIYANTO' 'LAKI - LAKI']
#  ['VICKY MAULANA' 'LAKI - LAKI']
#  ['MOCHAMAD HARTANTO' 'LAKI - LAKI']
#  ['PUTRA WAHYU WIJAYAKUSUMAH' 'LAKI - LAKI']
#  ["NAILIS SA'ADAH" 'PEREMPUAN']
#  ['ANWAR KHOERUDIN' 'LAKI - LAKI']
#  ['JOKO SANTOSO' 'LAKI - LAKI']
#  ['NOOR LATIFAH' 'PEREMPUAN']
#  ['DANANG WIDURI' 'PEREMPUAN']
#  ['SAIFUL AZAS KHASANUL MUNNA' 'LAKI - LAKI']
#  ['HANIK ROSIDAH' 'PEREMPUAN']
#  ['ATIQOH' 'PEREMPUAN']
#  ['SRI LESTARI' 'PEREMPUAN']
#  ['INGGIT BHINTAR HISKYATITIS' 'PEREMPUAN']
#  ['ULYA HIMMAWATI' 'PEREMPUAN']
#  ['HERU SAPUTRO' 'LAKI - LAKI']
#  ['ARIS SETYAWAN' 'LAKI - LAKI']
#  ['IMAM ZARKASYI' 'LAKI - LAKI']
#  ['FAJAR NOOR CAHYANTO' 'LAKI - LAKI']
#  ['NENENG FAIDA' 'PEREMPUAN']
#  ['ZULFA AMELIA' 'PEREMPUAN']
#  ['SUNARNO' 'LAKI - LAKI']
#  ['NOR FADLI' 'LAKI - LAKI']
#  ['USMAN ANDI WIBOWO' 'LAKI - LAKI']
#  ['SRI LESTARI' 'PEREMPUAN']
#  ['DEWI AYU KURNIA ALAM' 'PEREMPUAN']
#  ['NUR AFIFATULLAILA' 'PEREMPUAN']
#  ['MUSAUWAMATUL KHASANAH' 'PEREMPUAN']
#  ['ANANG RAMADHAN PANDU W' 'PEREMPUAN']
#  ['NURUL RICHA HIKMANINGSIH' 'PEREMPUAN']
#  ['MASKURI R' 'LAKI - LAKI']
#  ['BENNY KUSUMA AJI SANJAYA' 'LAKI - LAKI']
#  ['SUHIRMAN' 'LAKI - LAKI']
#  ['AKHSANUL HUDA' 'LAKI - LAKI']
#  ['AMIRUL CAHYO NUGROHO' 'LAKI - LAKI']
#  ['ACHMAD RIDWAN' 'LAKI - LAKI']
#  ['ENDAH PUJI ASTUTI' 'PEREMPUAN']
#  ['HERDA OSRA ANANTHEA' 'PEREMPUAN']
#  ['UNAMA' 'LAKI - LAKI']
#  ['LEYLA TRIYANA PRATIWI' 'PEREMPUAN']
#  ['VERIS SOFIYAN PRAYOGA' 'LAKI - LAKI']
#  ['ADITYA AKBAR NUGRAHA' 'LAKI - LAKI']
#  ['ERNA EKA RIYANTI' 'PEREMPUAN']
#  ['FARID DWI NORYANTO' 'LAKI - LAKI']
#  ['DAFIK HADI WINOTO' 'LAKI - LAKI']
#  ['WAHYU FITRIYANTO' 'LAKI - LAKI']
#  ['IMAM SURYO SUSANTO' 'LAKI - LAKI']
#  ['AHMAD SUTOPO' 'LAKI - LAKI']
#  ["HERI SUFA'AT" 'LAKI - LAKI']
#  ['MURYA AMIEN NUR PRABOWO' 'LAKI - LAKI']
#  ['EDY PURNOMO' 'LAKI - LAKI']
#  ['DIDIK KURNIAWAN' 'LAKI - LAKI']
#  ['LYDIA EVITA SANDRA DEWI' 'PEREMPUAN']
#  ['DAVID KURNIAWAN' 'LAKI - LAKI']
#  ['DEVI KISTIANI' 'PEREMPUAN']
#  ['ADI PURWADI' 'LAKI - LAKI']
#  ['ARIF WIBOWO' 'LAKI - LAKI']
#  ['NOVAZAEN DWI SAPUTRO' 'LAKI - LAKI']
#  ['MOHAMAD ADE FADHORI' 'LAKI - LAKI']
#  ['SUBAEDAH' 'PEREMPUAN']
#  ['DANI PRIMAYANTI' 'PEREMPUAN']
#  ['DERA BAHTIAR WIDIYANTO' 'LAKI - LAKI']
#  ['MUKHAMAD YAHYA WICAKSONO' 'LAKI - LAKI']
#  ['WAHYU DWI UTOMO' 'LAKI - LAKI']
#  ['AHMAD FIRDAUS MABRURI' 'LAKI - LAKI']
#  ['HARYOKO ABDUL HAMID' 'LAKI - LAKI']
#  ['ERSA GILANG ARDHANI' 'LAKI - LAKI']
#  ['NEORITA NUR FATIMAH' 'PEREMPUAN']
#  ['ULIL ALBAB' 'LAKI - LAKI']
#  ["DEWI KHOIRUN NISA'" 'PEREMPUAN']
#  ['AGUS NUGROHO' 'LAKI - LAKI']
#  ['MUKHAMAD LUQMAN HABIBI' 'LAKI - LAKI']
#  ['AMBAR SETIYANI' 'PEREMPUAN']
#  ['AVINA SEPTIANA' 'PEREMPUAN']
#  ['MARIA ULFA' 'PEREMPUAN']
#  ['IVANDHY SETYARACHMAN' 'LAKI - LAKI']
#  ['CHASAN MUBAROK' 'LAKI - LAKI']
#  ['HASMORO ANDI WINOTO' 'LAKI - LAKI']
#  ['NUR HAYATI' 'PEREMPUAN']
#  ['ROSIDA ARIBOWO' 'PEREMPUAN']
#  ['NOOR FAIZ' 'PEREMPUAN']
#  ['FITRIA ULFA' 'PEREMPUAN']
#  ['FANDI AHMAD' 'LAKI - LAKI']
#  ['FAJRI FANDILAH' 'LAKI - LAKI']
#  ['INDAH SUSILOWATI' 'PEREMPUAN']
#  ['RULY WIDYASTUTI' 'PEREMPUAN']
#  ['AWIT RIKA JAYA KUSUMA' 'LAKI - LAKI']
#  ['MUSLIMATUL MUFIROH' 'PEREMPUAN']
#  ['NOVIA PRASETYANINGRUM' 'PEREMPUAN']
#  ['MUH SAFAAT AGUNG MULYADI' 'LAKI - LAKI']
#  ['TAQIYUDDIN' 'LAKI - LAKI']
#  ['AGUS SETIAWAN' 'LAKI - LAKI']
#  ['TRI SETIAWAN' 'LAKI - LAKI']
#  ['WAHYUNI' 'PEREMPUAN']
#  ['FACHRY WICAKSONO' 'LAKI - LAKI']
#  ['MUNIF ROHMAWATI' 'PEREMPUAN']
#  ['LAILA HIDAYATI' 'PEREMPUAN']
#  ['ANDI PRASETYO' 'LAKI - LAKI']
#  ['NOOR YANTO' 'LAKI - LAKI']
#  ['HARYANTO' 'LAKI - LAKI']
#  ['FITROTUN MUNADLOFAH' 'PEREMPUAN']
#  ['FAHRUR ABID' 'LAKI - LAKI']
#  ['SLAMET RIYANTO' 'LAKI - LAKI']
#  ['KHOIRIL AINIAH' 'PEREMPUAN']
#  ['ADJI LISTIANSAH PRABOWO' 'LAKI - LAKI']
#  ['WAWAN MULYONO' 'LAKI - LAKI']
#  ['NENENG ZUBAIDAH' 'PEREMPUAN']
#  ['DINA FITHRONI' 'LAKI - LAKI']
#  ['KHOIRUL HADI PRANOTO' 'LAKI - LAKI']
#  ['DWI PUTRI ISNIATI' 'PEREMPUAN']
#  ['AGUSTINUS' 'LAKI - LAKI']
#  ['SHOFIL GUNAWAN' 'LAKI - LAKI']
#  ['ANIF FARIZI' 'LAKI - LAKI']
#  ['ALI NURSID' 'LAKI - LAKI']
#  ['DIDI MULYANTO' 'LAKI - LAKI']
#  ['ZULIATI' 'PEREMPUAN']
#  ['SITTA ROIHANA FITRI' 'PEREMPUAN']
#  ['JAMAL HENDRI PRASETIYO' 'LAKI - LAKI']
#  ['AUFAL WIDAD' 'LAKI - LAKI']
#  ['ZAENUDDIN MZ' 'LAKI - LAKI']
#  ['ARGI CAHYANING WULAN' 'PEREMPUAN']
#  ['EKO SUHERMAN' 'LAKI - LAKI']
#  ['AVIF ROHANA HERMAWAN' 'LAKI - LAKI']
#  ['ROBERT MYLLANO' 'LAKI - LAKI']
#  ['ABDUL LATIF' 'LAKI - LAKI']
#  ['AHMAD FAIZIN' 'LAKI - LAKI']
#  ['KHOIRUL ICHSAN' 'LAKI - LAKI']
#  ['DIAN AMALIA NOVIYANTI' 'PEREMPUAN']
#  ['KHOIRUL ULUM' 'LAKI - LAKI']
#  ['SAVITTA ANGGRAENI' 'PEREMPUAN']
#  ['ARIS HIDAYAT' 'LAKI - LAKI']
#  ["SHOFI'I" 'LAKI - LAKI']
#  ['SUMIATI' 'PEREMPUAN']
#  ['DWI ROY ARDIANTO SAPUTRO' 'LAKI - LAKI']
#  ["JAMA' ROCHMAD MUTTAQIM" 'LAKI - LAKI']
#  ['RIFDA NAUFALIN' 'PEREMPUAN']
#  ['MUHAMMAD YUSUF MEI HILDA' 'LAKI - LAKI']
#  ['YUIKE WIJAYANTI' 'PEREMPUAN']
#  ['ZIDNI ILMA' 'LAKI - LAKI']
#  ['FADLULLOH' 'LAKI - LAKI']
#  ["MUSTAANUN NA'IM" 'LAKI - LAKI']
#  ['MUAMAR ACHLIS AZIZI' 'LAKI - LAKI']
#  ['ZUMROTUN HALIMAH' 'PEREMPUAN']
#  ['HEMMI ZULAEKHAH' 'PEREMPUAN']
#  ['NURUL KHOFIANIDA' 'PEREMPUAN']
#  ['DEDY DANU SAPUTRA' 'LAKI - LAKI']
#  ['RUDY ADIATMA' 'LAKI - LAKI']
#  ['SITI MARIYANAH' 'PEREMPUAN']
#  ['FARIS RAHMAN' 'LAKI - LAKI']
#  ['BAMBANG ZAKKI SISWOYO' 'LAKI - LAKI']
#  ['FITRI KOMALASARI' 'PEREMPUAN']
#  ["NURUN NI'MAH" 'PEREMPUAN']
#  ['NOVITA ARYUNINGRUM' 'PEREMPUAN']
#  ['NURUL MISBAH' 'LAKI - LAKI']
#  ['MUNIF ABDILLAH' 'LAKI - LAKI']
#  ['MUHTAR HAFID' 'LAKI - LAKI']
#  ['MUHAMMAD DARUNNAFIS' 'LAKI - LAKI']
#  ['SITI NUR HIDAYATI' 'PEREMPUAN']
#  ['AFIEF BACHTIAR' 'LAKI - LAKI']
#  ['ALI AKBAR DAROJAT' 'LAKI - LAKI']
#  ['ITA SEPTIARINIE' 'PEREMPUAN']
#  ['DHANANG HERY WIBISONO' 'LAKI - LAKI']
#  ['NORMA FITRIYANI' 'PEREMPUAN']
#  ['ANIK FARYANTI' 'PEREMPUAN']
#  ['RIFQI ABDILLAH' 'LAKI - LAKI']
#  ['DAMA CHOIRUL HUDA' 'LAKI - LAKI']
#  ['AGUS SUPRIYO' 'LAKI - LAKI']
#  ['NOR JUNAIDI' 'LAKI - LAKI']
#  ['LILIK SUYATNO' 'LAKI - LAKI']
#  ['AMIR ALFIAN' 'LAKI - LAKI']
#  ['SURYAWAN ADHI SAPUTRO' 'LAKI - LAKI']
#  ['AGUS SETRIO PRANOTO' 'LAKI - LAKI']
#  ['ANIS WATUL WARDAH' 'PEREMPUAN']
#  ['ASROFAH' 'PEREMPUAN']
#  ['KUSNITA MARIANA' 'PEREMPUAN']
#  ['NOVI PURNAMASARI' 'PEREMPUAN']
#  ['AJI PRASETYO' 'LAKI - LAKI']
#  ['ABDUL ROSYID' 'LAKI - LAKI']
#  ['ARY JULI SETIYANTO' 'LAKI - LAKI']
#  ['RINA ZAHROTUL UMAMI' 'PEREMPUAN']
#  ['TULISA WAHYUHADI KRISNATAMI' 'PEREMPUAN']
#  ["NI'MATUL JANNAH" 'PEREMPUAN']
#  ['DINDU SETYO WICAKSONO' 'LAKI - LAKI']]

# %%
print(y)
# Out:
# ['TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
print(x_train)
# Out:
# [['FITROTUN MUNADLOFAH' 'PEREMPUAN']
#  ['EKA SETIYANI' 'PEREMPUAN']
#  ['NOVAN AIS SETIANSAH' 'LAKI - LAKI']
#  ['ROBI KORNIYAWAN' 'LAKI - LAKI']
#  ['PUTRA WAHYU WIJAYAKUSUMAH' 'LAKI - LAKI']
#  ['SITI NUR HIDAYATI' 'PEREMPUAN']
#  ['IVANDHY SETYARACHMAN' 'LAKI - LAKI']
#  ['AGUSTINA SETIONINGSIH' 'PEREMPUAN']
#  ['ARIEF PRAM WAHYUDI' 'LAKI - LAKI']
#  ['DEWI AYU KURNIA ALAM' 'PEREMPUAN']
#  ['TUTIK KHOTIMAH' 'PEREMPUAN']
#  ['HANIK ROSIDAH' 'PEREMPUAN']
#  ['NURUL KHOFIANIDA' 'PEREMPUAN']
#  ['DINDU SETYO WICAKSONO' 'LAKI - LAKI']
#  ['EMAWANTI' 'PEREMPUAN']
#  ['UMMIA WULAN SARI' 'PEREMPUAN']
#  ['IWAN HAMBALI' 'PEREMPUAN']
#  ['SUMARLAN' 'LAKI - LAKI']
#  ['NOOR YANTO' 'LAKI - LAKI']
#  ['ADI JOKO MULYONO' 'LAKI - LAKI']
#  ['SHOFIL GUNAWAN' 'LAKI - LAKI']
#  ['ARIS SETYAWAN' 'LAKI - LAKI']
#  ['ADI SUBEKTI' 'LAKI - LAKI']
#  ['UNAMA' 'LAKI - LAKI']
#  ['WIWID WAHYUDI' 'LAKI - LAKI']
#  ['SUGENG RIYANTO' 'LAKI - LAKI']
#  ['GUNUNG WICAKSONO' 'LAKI - LAKI']
#  ['DEVI KISTIANI' 'PEREMPUAN']
#  ['GUNA SETIAWAN' 'LAKI - LAKI']
#  ['MIFTAKHULIL SETIYANING HIDAYAH' 'PEREMPUAN']
#  ['KUMALA DEWI' 'LAKI - LAKI']
#  ['TAUFIK SETYAWAN' 'LAKI - LAKI']
#  ['SURYAWAN ADHI SAPUTRO' 'LAKI - LAKI']
#  ['FAJAR NOOR CAHYANTO' 'LAKI - LAKI']
#  ['WAHYU SETIYA BUDI' 'LAKI - LAKI']
#  ['MUTIARA FANNY' 'PEREMPUAN']
#  ['ZULIATI' 'PEREMPUAN']
#  ['ARUM PURWANINGSIH' 'PEREMPUAN']
#  ['MUH SAIFUL MUBAROK' 'LAKI - LAKI']
#  ['WAHYU FITRIYANTO' 'LAKI - LAKI']
#  ['INDAH SUSILOWATI' 'PEREMPUAN']
#  ['HARYOKO ABDUL HAMID' 'LAKI - LAKI']
#  ['IKA MUSTIANA' 'PEREMPUAN']
#  ['SAIRUN NICHLAH' 'PEREMPUAN']
#  ['MUSLIMATUL MUFIROH' 'PEREMPUAN']
#  ['AGUS NUGROHO' 'LAKI - LAKI']
#  ['MUHAMAD FAUZI' 'LAKI - LAKI']
#  ['SRI MINUK ISWATI' 'LAKI - LAKI']
#  ['DHANANG HERY WIBISONO' 'LAKI - LAKI']
#  ['SUDANDING DWI SUPRABANA' 'LAKI - LAKI']
#  ['ITA SEPTIARINIE' 'PEREMPUAN']
#  ['RUDIYANTI SETIASIH' 'PEREMPUAN']
#  ['MUCHAMMAD BAHRUDIN' 'LAKI - LAKI']
#  ['ACHMAD RIDWAN' 'LAKI - LAKI']
#  ['ANDI PRASETYO' 'LAKI - LAKI']
#  ['ARIE RETNO WATI' 'PEREMPUAN']
#  ['KUSNITA MARIANA' 'PEREMPUAN']
#  ['NOVIA PRASETYANINGRUM' 'PEREMPUAN']
#  ["ULFAH NOR SA'ADAH" 'PEREMPUAN']
#  ['YUSTINUS ARI SETIAWAN' 'LAKI - LAKI']
#  ["A SYAFI'I" 'LAKI - LAKI']
#  ['NENENG ZUBAIDAH' 'PEREMPUAN']
#  ['MOCHAMAD IDRIS' 'LAKI - LAKI']
#  ['AHMAD FAIZIN' 'LAKI - LAKI']
#  ['HERU NOR RACHMAD' 'LAKI - LAKI']
#  ['NOOR ISYA' 'LAKI - LAKI']
#  ['RIFQI ABDILLAH' 'LAKI - LAKI']
#  ['HERDA OSRA ANANTHEA' 'PEREMPUAN']
#  ['RINA ZAHROTUL UMAMI' 'PEREMPUAN']
#  ['NOOR KAMALUDDIN MALIK' 'LAKI - LAKI']
#  ['CHASAN MUBAROK' 'LAKI - LAKI']
#  ['AGUS SUSILO' 'LAKI - LAKI']
#  ['ALI NURSID' 'LAKI - LAKI']
#  ['RIFDA NAUFALIN' 'PEREMPUAN']
#  ['NAILI ROHMAH' 'PEREMPUAN']
#  ['DIDIK KURNIAWAN' 'LAKI - LAKI']
#  ['IMAM ZARKASYI' 'LAKI - LAKI']
#  ['TAUFIK RAMADHAN' 'LAKI - LAKI']
#  ['MOCHAMAD HARTANTO' 'LAKI - LAKI']
#  ['ALI AKBAR DAROJAT' 'LAKI - LAKI']
#  ['RIZAL BACHTIAR' 'LAKI - LAKI']
#  ['ANANG RAMADHAN PANDU W' 'PEREMPUAN']
#  ['IRWAN HIDAYAT' 'LAKI - LAKI']
#  ['AHMAD FIRDAUS MABRURI' 'LAKI - LAKI']
#  ['ULIL ALBAB' 'LAKI - LAKI']
#  ['SUGIYANTO' 'LAKI - LAKI']
#  ['EDY PURNOMO' 'LAKI - LAKI']
#  ['ARIF WIBOWO' 'LAKI - LAKI']
#  ['DAVID KURNIAWAN' 'LAKI - LAKI']
#  ['LYDIA EVITA SANDRA DEWI' 'PEREMPUAN']
#  ['TATIK HIKMAWATI' 'LAKI - LAKI']
#  ['ULYA HIMMAWATI' 'PEREMPUAN']
#  ['INDAH NOR KHAYATI' 'PEREMPUAN']
#  ['PUTRI KURNIA HANDAYANI' 'PEREMPUAN']
#  ['EDY KUSMANTO' 'PEREMPUAN']
#  ['MUHAMMAD TAHRIR FATHONY' 'LAKI - LAKI']
#  ['NEORITA NUR FATIMAH' 'PEREMPUAN']
#  ['WAHYU DWI UTOMO' 'LAKI - LAKI']
#  ['DAFIK HADI WINOTO' 'LAKI - LAKI']
#  ['AHMAD IBROZI' 'LAKI - LAKI']
#  ['AVINA SEPTIANA' 'PEREMPUAN']
#  ['MEILINDA IKA WIJAYANTI' 'PEREMPUAN']
#  ['NOR FADLI' 'LAKI - LAKI']
#  ['SRI LESTARI' 'PEREMPUAN']
#  ['HAROZUM' 'PEREMPUAN']
#  ['AGUS SETRIO PRANOTO' 'LAKI - LAKI']
#  ['AVIF ROHANA HERMAWAN' 'LAKI - LAKI']
#  ['LILIK SUYATNO' 'LAKI - LAKI']
#  ['ASROFAH' 'PEREMPUAN']
#  ['DEWI KARYASARI' 'PEREMPUAN']
#  ['TRI MULYANTO' 'LAKI - LAKI']
#  ['ROSIDI' 'LAKI - LAKI']
#  ['MOH ERIK CHANDRA IRVANA' 'LAKI - LAKI']
#  ['MOHAMMAD RIFQI ABDILLAH' 'LAKI - LAKI']
#  ['TULISA WAHYUHADI KRISNATAMI' 'PEREMPUAN']
#  ['SYARIEF WIRA ADMAJA' 'LAKI - LAKI']
#  ['MUSAUWAMATUL KHASANAH' 'PEREMPUAN']
#  ['NOVAZAEN DWI SAPUTRO' 'LAKI - LAKI']
#  ['SRI LESTARI' 'PEREMPUAN']
#  ['AFIEF BACHTIAR' 'LAKI - LAKI']
#  ['PRATIWI PUJIASTUTI' 'PEREMPUAN']
#  ['JOHAN MAULANA' 'LAKI - LAKI']
#  ['MOH SYAIKHUDDIN' 'LAKI - LAKI']
#  ['HERU DARMAWAN' 'LAKI - LAKI']
#  ['EDI JATMIKO' 'PEREMPUAN']
#  ['MOHAMAD ADE FADHORI' 'LAKI - LAKI']
#  ['IWAN SETYO ASMOKO' 'LAKI - LAKI']
#  ['DANNY NOVRIYANTO' 'LAKI - LAKI']
#  ['ANIF FARIZI' 'LAKI - LAKI']
#  ['SAIFUL AZAS KHASANUL MUNNA' 'LAKI - LAKI']
#  ['FITRI KOMALASARI' 'PEREMPUAN']
#  ['ISNANTO HENDRO YULIHARSO' 'LAKI - LAKI']
#  ['AJI PRASETYO' 'LAKI - LAKI']
#  ['RIFKA ISTIQFARINA' 'PEREMPUAN']
#  ['ROFIDA RONING MAHANONDA' 'PEREMPUAN']
#  ['DIANA LAILY FITHRI' 'PEREMPUAN']
#  ['DIAH KUSUMANINGTYAS' 'PEREMPUAN']
#  ['ERFANA SETIYANINGRUM' 'PEREMPUAN']
#  ['WAWAN MULYONO' 'LAKI - LAKI']
#  ['ENI ISNAWATI' 'PEREMPUAN']
#  ['PURWADI' 'LAKI - LAKI']
#  ['FARID DWI NORYANTO' 'LAKI - LAKI']
#  ['ZAENUDDIN MZ' 'LAKI - LAKI']
#  ['ANDI HARDIANTO' 'LAKI - LAKI']
#  ['MUHAMMAD DARUNNAFIS' 'LAKI - LAKI']
#  ['EKO JAUHARI SAPUTRO' 'LAKI - LAKI']
#  ['LAILI QODRIYAH' 'PEREMPUAN']
#  ['M SYAIFULLAH' 'PEREMPUAN']
#  ['YUDA LINDA PRATIWI' 'PEREMPUAN']
#  ['MASKURI R' 'LAKI - LAKI']
#  ['WAHYUNI' 'PEREMPUAN']
#  ['NANIK SUSANTI' 'PEREMPUAN']
#  ['MURYA ARIEF BASUKI' 'PEREMPUAN']
#  ['NIRWANA SATRIA PAMBUDI' 'LAKI - LAKI']
#  ['MARTHINA FLAVERIA' 'LAKI - LAKI']
#  ['ROHANA MIRAWATI' 'LAKI - LAKI']
#  ['KOMARUDIN FARUQ' 'LAKI - LAKI']
#  ['ENDAH PUJI ASTUTI' 'PEREMPUAN']
#  ['NISFISYA MUSWARDINI' 'PEREMPUAN']
#  ['BADRUDDIN' 'LAKI - LAKI']
#  ['MUNIF ABDILLAH' 'LAKI - LAKI']
#  ['RUDY ADIATMA' 'LAKI - LAKI']
#  ['NORMA FITRIYANI' 'PEREMPUAN']
#  ['SAVITTA ANGGRAENI' 'PEREMPUAN']
#  ['SITI SUSANAH' 'PEREMPUAN']
#  ["NURUN NI'MAH" 'PEREMPUAN']
#  ['MIFTAHUL HUDA' 'LAKI - LAKI']
#  ['MUKHAMAD YAHYA WICAKSONO' 'LAKI - LAKI']
#  ['IRFAN EKO WAHYUDI' 'PEREMPUAN']
#  ['AWIT RIKA JAYA KUSUMA' 'LAKI - LAKI']
#  ['MUHAMMAD ABDUH' 'LAKI - LAKI']
#  ['SUSI  HANDAYANI' 'LAKI - LAKI']
#  ['DAMA CHOIRUL HUDA' 'LAKI - LAKI']
#  ['BAGUS WIBOWO HERRU PRIHANTO' 'LAKI - LAKI']
#  ['HARMINTO MULYO' 'LAKI - LAKI']
#  ['AGUNG WIDODO' 'LAKI - LAKI']
#  ['INGGIT BHINTAR HISKYATITIS' 'PEREMPUAN']
#  ['KHOIRIL AINIAH' 'PEREMPUAN']
#  ['SLAMET RIYANTO' 'LAKI - LAKI']
#  ['SITTA ROIHANA FITRI' 'PEREMPUAN']
#  ['DWI SISWANTO' 'LAKI - LAKI']
#  ['NUR AFIFATULLAILA' 'PEREMPUAN']
#  ['EDI HARIYANTO' 'LAKI - LAKI']
#  ['TAQIYUDDIN' 'LAKI - LAKI']
#  ['MUHAMMAD ARIF WIBOWO' 'LAKI - LAKI']
#  ['EVY DIAH HAPSARI' 'PEREMPUAN']
#  ['DENNY SELA PUTROWIBOWO' 'LAKI - LAKI']
#  ['MIFTACHUR RIDHO' 'LAKI - LAKI']
#  ['ANIK WIDAYANTI' 'PEREMPUAN']
#  ['ANWAR KHOERUDIN' 'LAKI - LAKI']
#  ['ROBERT MYLLANO' 'LAKI - LAKI']
#  ['SHOFIA NUR JAMILA' 'PEREMPUAN']
#  ["KHOTIMATUS SA'ADAH" 'PEREMPUAN']
#  ['DANI PRIMAYANTI' 'PEREMPUAN']
#  ['REZA PAHLEVI' 'LAKI - LAKI']
#  ['NOVITA ARYUNINGRUM' 'PEREMPUAN']
#  ['RINA WARDANI' 'PEREMPUAN']
#  ["JAMA' ROCHMAD MUTTAQIM" 'LAKI - LAKI']
#  ['ERVINA DWI WIJAYANTI' 'PEREMPUAN']
#  ['FITRIA HANDAYANI' 'PEREMPUAN']
#  ['ACHMAD FAHMI AQWA' 'LAKI - LAKI']
#  ['ATIQOH' 'PEREMPUAN']
#  ['FAJRI FANDILAH' 'LAKI - LAKI']
#  ['BENNY KUSUMA AJI SANJAYA' 'LAKI - LAKI']
#  ['ANDRE EKA SETYAWAN' 'LAKI - LAKI']
#  ['GAMA FARID DENA' 'LAKI - LAKI']
#  ['MUHAMMAD SETIAWAN' 'LAKI - LAKI']
#  ['MOHAMAD ABDUL AZIS' 'LAKI - LAKI']
#  ["MUSTAANUN NA'IM" 'LAKI - LAKI']
#  ["NI'MATUL JANNAH" 'PEREMPUAN']
#  ['ERSA GILANG ARDHANI' 'LAKI - LAKI']
#  ['NOOR LATIFAH' 'PEREMPUAN']
#  ['MOKHAMAD ALEX KHOIRUDIN' 'LAKI - LAKI']
#  ['MUHKHAMAD FAKHRUL HIDAYAT' 'LAKI - LAKI']
#  ['KHOIRUL ULUM' 'LAKI - LAKI']
#  ['BAMBANG ZAKKI SISWOYO' 'LAKI - LAKI']
#  ['NOOR MUHAMMAD AFIF' 'LAKI - LAKI']
#  ['MOCHAMAD IRWANSYAH' 'LAKI - LAKI']
#  ['MUKHAMAD LUQMAN HABIBI' 'LAKI - LAKI']
#  ['ISMI NUR FAJRIAH' 'PEREMPUAN']
#  ['MUNIF ROHMAWATI' 'PEREMPUAN']
#  ['ARIEF SETIAWAN' 'LAKI - LAKI']
#  ['DERA BAHTIAR WIDIYANTO' 'LAKI - LAKI']
#  ['ZIDNI ILMA' 'LAKI - LAKI']
#  ['HERI PURWANTO' 'LAKI - LAKI']
#  ['TUGIYO' 'LAKI - LAKI']
#  ['HASMORO ANDI WINOTO' 'LAKI - LAKI']
#  ['MUHAMMAD YUSUF MEI HILDA' 'LAKI - LAKI']
#  ['TOTOK ANTON ARIBOWO' 'LAKI - LAKI']
#  ['AGUS RIYANTO' 'LAKI - LAKI']
#  ['ARIS HIDAYAT' 'LAKI - LAKI']
#  ['NOOR FAIS' 'PEREMPUAN']
#  ['FACHRY WICAKSONO' 'LAKI - LAKI']
#  ['NASRUL SAFARAH' 'LAKI - LAKI']
#  ['ARDI SETIAWAN' 'LAKI - LAKI']
#  ['MIFTAKHUL HABIB' 'LAKI - LAKI']
#  ['NURUL KHOIRIYAH' 'PEREMPUAN']
#  ["HERI SUFA'AT" 'LAKI - LAKI']
#  ['JOKO SANTOSO' 'LAKI - LAKI']
#  ['SANDY YUDHA NUGRAHA' 'LAKI - LAKI']
#  ['SISKA LIANAWATI' 'LAKI - LAKI']
#  ['AYU NAWAKSARI' 'PEREMPUAN']
#  ['PRASTIWI SETIYOWATI' 'PEREMPUAN']
#  ['MUHTAR HAFID' 'LAKI - LAKI']
#  ['TRI SETIAWAN' 'LAKI - LAKI']
#  ['DEDY DANU SAPUTRA' 'LAKI - LAKI']
#  ['EVA ADITYA' 'PEREMPUAN']
#  ['MUH SAFAAT AGUNG MULYADI' 'LAKI - LAKI']
#  ['NURUL MISBAH' 'LAKI - LAKI']
#  ['DEWI ASTUTI' 'PEREMPUAN']
#  ['SIGIT SETYO ATMOKO' 'PEREMPUAN']
#  ['ZUMROTUN HALIMAH' 'PEREMPUAN']
#  ['FADLULLOH' 'LAKI - LAKI']
#  ['VICKY MAULANA' 'LAKI - LAKI']
#  ['AHMAD SUTOPO' 'LAKI - LAKI']
#  ['MASYKURI' 'LAKI - LAKI']
#  ["DEWI KHOIRUN NISA'" 'PEREMPUAN']
#  ['HERMAWAN BUDI HARTONO' 'LAKI - LAKI']
#  ['YUIKE WIJAYANTI' 'PEREMPUAN']
#  ['MASLUH JAMIL' 'LAKI - LAKI']
#  ['ANIK MURWATI' 'PEREMPUAN']
#  ['MUAMAR ACHLIS AZIZI' 'LAKI - LAKI']
#  ['NOR JUNAIDI' 'LAKI - LAKI']
#  ['NOOR FARIDA' 'PEREMPUAN']
#  ['AMIR ALFIAN' 'LAKI - LAKI']
#  ['ADI DARMADI' 'LAKI - LAKI']
#  ['SITI CHODIROH' 'PEREMPUAN']
#  ['AUFAL WIDAD' 'LAKI - LAKI']
#  ['MUHAMMAD AMINAN' 'LAKI - LAKI']
#  ['FITYATUN FATAYAH' 'PEREMPUAN']
#  ['MUHAMMAD ABDUL AZIS' 'LAKI - LAKI']
#  ['LAILA HIDAYATI' 'PEREMPUAN']
#  ['IMAM SURYO SUSANTO' 'LAKI - LAKI']
#  ['FITRIA ULFA' 'PEREMPUAN']
#  ['HERU SAPUTRO' 'LAKI - LAKI']
#  ['IMAM AGUNG RIBOWO' 'PEREMPUAN']
#  ['ANIK FARYANTI' 'PEREMPUAN']
#  ['AKHMAD ZAINUDIN' 'LAKI - LAKI']
#  ['ADI PURWADI' 'LAKI - LAKI']
#  ['DIAN AMALIA NOVIYANTI' 'PEREMPUAN']
#  ['AFTONAL FALAKH' 'LAKI - LAKI']
#  ['HERU WIJAYANTO' 'LAKI - LAKI']
#  ["ABDUL GHOFFAR ISMA'IL" 'LAKI - LAKI']
#  ['NILA OCTARINA' 'PEREMPUAN']]

# %%
print(x_test)
# Out:
# [['KARSONO HENDI' 'LAKI - LAKI']
#  ['AGUSTINUS' 'LAKI - LAKI']
#  ['ROSIDA ARIBOWO' 'PEREMPUAN']
#  ['MARIA ULFA' 'PEREMPUAN']
#  ['NENENG FAIDA' 'PEREMPUAN']
#  ['LINA NAILAL MUNA' 'PEREMPUAN']
#  ['AGUS SUPRIYO' 'LAKI - LAKI']
#  ['EMAN PRASOJO' 'LAKI - LAKI']
#  ['SUNARSO' 'LAKI - LAKI']
#  ['USWATUN KHASANAH' 'LAKI - LAKI']
#  ['NOOR FAIZ' 'PEREMPUAN']
#  ['ANIS WATUL WARDAH' 'PEREMPUAN']
#  ['MURYA AMIEN NUR PRABOWO' 'LAKI - LAKI']
#  ['MARWANTO WIJANARKO' 'LAKI - LAKI']
#  ['FAHRUR ABID' 'LAKI - LAKI']
#  ['DEFI MAULA KHORIDA' 'PEREMPUAN']
#  ['HARYANTO' 'LAKI - LAKI']
#  ['PUTRI RETNO ARIYANI' 'PEREMPUAN']
#  ['ALINA INDRAWATI' 'PEREMPUAN']
#  ["SHOFI'I" 'LAKI - LAKI']
#  ['ABDUL ROSYID' 'LAKI - LAKI']
#  ['DANANG MAHENDRA' 'LAKI - LAKI']
#  ['SUNARNO' 'LAKI - LAKI']
#  ['ARY JULI SETIYANTO' 'LAKI - LAKI']
#  ['FITRIANA MASRUROH' 'PEREMPUAN']
#  ["NI'MATUL KHASANAH" 'PEREMPUAN']
#  ['ARIF BUDIYANTO' 'LAKI - LAKI']
#  ['AKHSANUL HUDA' 'LAKI - LAKI']
#  ['NUR HAYATI' 'PEREMPUAN']
#  ['LEYLA TRIYANA PRATIWI' 'PEREMPUAN']
#  ['JAMAL HENDRI PRASETIYO' 'LAKI - LAKI']
#  ['FARIKHATUN NAZLI' 'PEREMPUAN']
#  ['DWI HESTYNA PRIHASTANTY' 'PEREMPUAN']
#  ['RULY WIDYASTUTI' 'PEREMPUAN']
#  ['SUTOPO' 'LAKI - LAKI']
#  ['SUYONO' 'LAKI - LAKI']
#  ['SAIFUL ANAM' 'LAKI - LAKI']
#  ['WAHYUNI' 'PEREMPUAN']
#  ['FARCHAN NOVE INDRIYANTO' 'LAKI - LAKI']
#  ['ZULFA AMELIA' 'PEREMPUAN']
#  ['IMAM SANTOSA' 'PEREMPUAN']
#  ['MURDIANTORO' 'LAKI - LAKI']
#  ['DEVI RIESTYANINGSIH' 'PEREMPUAN']
#  ['ABDUL LATIF' 'LAKI - LAKI']
#  ['ARGI CAHYANING WULAN' 'PEREMPUAN']
#  ['FARIS RAHMAN' 'LAKI - LAKI']
#  ['KHOIRUL HADI PRANOTO' 'LAKI - LAKI']
#  ['DONNY PRABOWO' 'LAKI - LAKI']
#  ['AGUS BUDI UTOMO' 'LAKI - LAKI']
#  ['SUBAEDAH' 'PEREMPUAN']
#  ['SUHARYONO' 'LAKI - LAKI']
#  ['SUGIYANTO' 'LAKI - LAKI']
#  ["KHAMIM MASYFU'I" 'LAKI - LAKI']
#  ['FIFI SUNALISA' 'PEREMPUAN']
#  ['ADJI LISTIANSAH PRABOWO' 'LAKI - LAKI']
#  ['M IMAM MUSLIMIN' 'LAKI - LAKI']
#  ['EKO SUHERMAN' 'LAKI - LAKI']
#  ['SUHIRMAN' 'LAKI - LAKI']
#  ['FANDI AHMAD' 'LAKI - LAKI']
#  ['ANDI SUNARWAN' 'LAKI - LAKI']
#  ['NOVI PURNAMASARI' 'PEREMPUAN']
#  ['DANANG WIDURI' 'PEREMPUAN']
#  ['AMIRUL CAHYO NUGROHO' 'LAKI - LAKI']
#  ['HEMMI ZULAEKHAH' 'PEREMPUAN']
#  ['INDRI ERNAMAWATI' 'PEREMPUAN']
#  ['DWI PUTRI ISNIATI' 'PEREMPUAN']
#  ['NURUL RICHA HIKMANINGSIH' 'PEREMPUAN']
#  ['EMA SYAROH' 'PEREMPUAN']
#  ['ANDY MAHENDRA' 'LAKI - LAKI']
#  ['SITI MARIYANAH' 'PEREMPUAN']
#  ["NAILIS SA'ADAH" 'PEREMPUAN']
#  ['DIDI MULYANTO' 'LAKI - LAKI']
#  ['VERIS SOFIYAN PRAYOGA' 'LAKI - LAKI']
#  ['ERNA EKA RIYANTI' 'PEREMPUAN']
#  ['AGUS SETIAWAN' 'LAKI - LAKI']
#  ['ARIEF IRFANDIANSYAH' 'LAKI - LAKI']
#  ['HENDRIK MULIYANTO' 'PEREMPUAN']
#  ['MOH IQBAL HAKIM' 'LAKI - LAKI']
#  ['DINA FITHRONI' 'LAKI - LAKI']
#  ['ADITYA AKBAR NUGRAHA' 'LAKI - LAKI']
#  ['DWI ROY ARDIANTO SAPUTRO' 'LAKI - LAKI']
#  ['MOHAMAD ASNAWI' 'LAKI - LAKI']
#  ['USMAN ANDI WIBOWO' 'LAKI - LAKI']
#  ['EDI PURNOMO' 'LAKI - LAKI']
#  ['KHOIRUL ICHSAN' 'LAKI - LAKI']
#  ['AMBAR SETIYANI' 'PEREMPUAN']
#  ['MOCH LUTFIANTO' 'LAKI - LAKI']
#  ['SUMIATI' 'PEREMPUAN']
#  ['NISWATUL ALIYAH' 'PEREMPUAN']
#  ['MUHAMMAD YASIN YUSUF' 'LAKI - LAKI']
#  ['FIRMAN HAQIQI' 'LAKI - LAKI']
#  ['ANNY AZIZAH' 'LAKI - LAKI']
#  ['TRI PUJI LESTARI' 'PEREMPUAN']
#  ['MOH AINUL YAQIN' 'LAKI - LAKI']
#  ['ADY PRASETIA' 'LAKI - LAKI']]

# %%
print(y_train)
# Out:
# ['TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT'
#  'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT']

# %%
print(y_test)
# Out:
# ['TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TEPAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT'
#  'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT'
#  'TERLAMBAT' 'TERLAMBAT' 'TEPAT' 'TERLAMBAT' 'TERLAMBAT']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17712\13500210.py in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 x_train = sc.fit_transform(x_train)
#       4 x_test = sc.fit_transform(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     839         """
#     840         first_call = not hasattr(self, "n_samples_seen_")
# --> 841         X = self._validate_data(
#     842             X,
#     843             accept_sparse=("csr", "csc"),
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ValueError: could not convert string to float: 'FITROTUN MUNADLOFAH'
